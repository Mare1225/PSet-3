# %%
from pyspark.sql import SparkSession, functions as F, types as T
from pyspark import SparkConf
from dotenv import load_dotenv
import os
from datetime import datetime
import pandas as pd

# %%
query_counts = """
SELECT
    YEAR,
    MONTH,
    SERVICE_TYPE,
    COUNT(*) AS total_viajes,
    ROUND(AVG(TRIP_DISTANCE), 2) AS avg_distance,
    ROUND(MAX(TRIP_DISTANCE), 2) AS max_distance,
    ROUND(MIN(TRIP_DISTANCE), 2) AS min_distance,
    ROUND(AVG(TOTAL_AMOUNT), 2) AS avg_total_amount,
    ROUND(MAX(TOTAL_AMOUNT), 2) AS max_total_amount,
    ROUND(MIN(TOTAL_AMOUNT), 2) AS min_total_amount
FROM STAGE.OBT_TRIPS
GROUP BY YEAR, MONTH, SERVICE_TYPE
ORDER BY YEAR, MONTH, SERVICE_TYPE;
"""

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    #Se tiene que cambiar a los secretosAAAAAAA
    user="MARE122510",
    password="MyTurnEra2025100%",
    account="TLZAPUN-PKC06603",
    warehouse="COMPUTE_WH",
    database="NY_TAXI",
    schema="STAGE",
    role =os.getenv('ROLE')
)

cur = conn.cursor()
cur.execute(query_counts)
print("cursor creado")
results = cur.fetchall()

# Obtener nombres de columnas
columns = [desc[0] for desc in cur.description]

# Mostrar como tabla
for row in results:
    print(dict(zip(columns, row)))

cur.close()
# Out:
# cursor creado
# {'YEAR': 2000, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 18, 'AVG_DISTANCE': 5.55, 'MAX_DISTANCE': 20.77, 'MIN_DISTANCE': 0.11, 'AVG_TOTAL_AMOUNT': 27.62, 'MAX_TOTAL_AMOUNT': 98.76, 'MIN_TOTAL_AMOUNT': 3.8}
# {'YEAR': 2001, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4, 'AVG_DISTANCE': 3.83, 'MAX_DISTANCE': 9.13, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 21.85, 'MAX_TOTAL_AMOUNT': 43.0, 'MIN_TOTAL_AMOUNT': 3.3}
# {'YEAR': 2001, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 3.8, 'MAX_TOTAL_AMOUNT': 3.8, 'MIN_TOTAL_AMOUNT': 3.8}
# {'YEAR': 2001, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 7.08, 'MAX_DISTANCE': 7.08, 'MIN_DISTANCE': 7.08, 'AVG_TOTAL_AMOUNT': 24.55, 'MAX_TOTAL_AMOUNT': 24.55, 'MIN_TOTAL_AMOUNT': 24.55}
# {'YEAR': 2002, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11, 'AVG_DISTANCE': 2.93, 'MAX_DISTANCE': 11.28, 'MIN_DISTANCE': 0.48, 'AVG_TOTAL_AMOUNT': 17.9, 'MAX_TOTAL_AMOUNT': 44.42, 'MIN_TOTAL_AMOUNT': 7.8}
# {'YEAR': 2002, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 439, 'AVG_DISTANCE': 3.92, 'MAX_DISTANCE': 62.55, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.77, 'MAX_TOTAL_AMOUNT': 260.3, 'MIN_TOTAL_AMOUNT': -76.35}
# {'YEAR': 2002, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 78, 'AVG_DISTANCE': 6.3, 'MAX_DISTANCE': 31.43, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 29.73, 'MAX_TOTAL_AMOUNT': 169.1, 'MIN_TOTAL_AMOUNT': -10.5}
# {'YEAR': 2003, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4, 'AVG_DISTANCE': 5.21, 'MAX_DISTANCE': 20.85, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.47, 'MAX_TOTAL_AMOUNT': 58.56, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2003, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 3.31, 'MAX_TOTAL_AMOUNT': 3.31, 'MIN_TOTAL_AMOUNT': 3.31}
# {'YEAR': 2003, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 1.21, 'MAX_DISTANCE': 1.21, 'MIN_DISTANCE': 1.21, 'AVG_TOTAL_AMOUNT': 7.3, 'MAX_TOTAL_AMOUNT': 7.3, 'MIN_TOTAL_AMOUNT': 7.3}
# {'YEAR': 2004, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 1.59, 'MAX_DISTANCE': 1.59, 'MIN_DISTANCE': 1.59, 'AVG_TOTAL_AMOUNT': 12.3, 'MAX_TOTAL_AMOUNT': 12.3, 'MIN_TOTAL_AMOUNT': 12.3}
# {'YEAR': 2007, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 3.0, 'MAX_DISTANCE': 3.0, 'MIN_DISTANCE': 3.0, 'AVG_TOTAL_AMOUNT': 22.75, 'MAX_TOTAL_AMOUNT': 22.75, 'MIN_TOTAL_AMOUNT': 22.75}
# {'YEAR': 2008, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 0.66, 'MAX_DISTANCE': 1.15, 'MIN_DISTANCE': 0.42, 'AVG_TOTAL_AMOUNT': 4.32, 'MAX_TOTAL_AMOUNT': 12.96, 'MIN_TOTAL_AMOUNT': -7.3}
# {'YEAR': 2008, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2008, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 363, 'AVG_DISTANCE': 2.77, 'MAX_DISTANCE': 101.87, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 12.97, 'MAX_TOTAL_AMOUNT': 132.6, 'MIN_TOTAL_AMOUNT': -7.8}
# {'YEAR': 2008, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1582, 'AVG_DISTANCE': 4.11, 'MAX_DISTANCE': 62.26, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 21.03, 'MAX_TOTAL_AMOUNT': 266.82, 'MIN_TOTAL_AMOUNT': -69.36}
# {'YEAR': 2009, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 65, 'AVG_DISTANCE': 7.78, 'MAX_DISTANCE': 32.58, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 29.81, 'MAX_TOTAL_AMOUNT': 149.3, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2009, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 279, 'AVG_DISTANCE': 4.23, 'MAX_DISTANCE': 34.47, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 21.45, 'MAX_TOTAL_AMOUNT': 99.88, 'MIN_TOTAL_AMOUNT': -3.3}
# {'YEAR': 2010, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 2.79, 'MAX_DISTANCE': 2.79, 'MIN_DISTANCE': 2.79, 'AVG_TOTAL_AMOUNT': 18.36, 'MAX_TOTAL_AMOUNT': 18.36, 'MIN_TOTAL_AMOUNT': 18.36}
# {'YEAR': 2010, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 348, 'AVG_DISTANCE': 3.66, 'MAX_DISTANCE': 26.91, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.95, 'MAX_TOTAL_AMOUNT': 152.16, 'MIN_TOTAL_AMOUNT': -5.3}
# {'YEAR': 2011, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4, 'AVG_DISTANCE': 1.81, 'MAX_DISTANCE': 2.98, 'MIN_DISTANCE': 0.36, 'AVG_TOTAL_AMOUNT': 13.89, 'MAX_TOTAL_AMOUNT': 18.8, 'MIN_TOTAL_AMOUNT': 6.8}
# {'YEAR': 2012, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2012, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 1.35, 'MAX_DISTANCE': 2.6, 'MIN_DISTANCE': 0.6, 'AVG_TOTAL_AMOUNT': 9.79, 'MAX_TOTAL_AMOUNT': 14.3, 'MIN_TOTAL_AMOUNT': 6.3}
# {'YEAR': 2014, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 6.43, 'MAX_DISTANCE': 6.43, 'MIN_DISTANCE': 6.43, 'AVG_TOTAL_AMOUNT': 52.38, 'MAX_TOTAL_AMOUNT': 52.38, 'MIN_TOTAL_AMOUNT': 52.38}
# {'YEAR': 2014, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 61378, 'AVG_DISTANCE': 3.32, 'MAX_DISTANCE': 77.42, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.69, 'MAX_TOTAL_AMOUNT': 400.0, 'MIN_TOTAL_AMOUNT': -135.5}
# {'YEAR': 2014, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 129456, 'AVG_DISTANCE': 3.25, 'MAX_DISTANCE': 228.4, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.2, 'MAX_TOTAL_AMOUNT': 300.8, 'MIN_TOTAL_AMOUNT': -73.3}
# {'YEAR': 2015, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 2971856, 'AVG_DISTANCE': 2.76, 'MAX_DISTANCE': 830.4, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.76, 'MAX_TOTAL_AMOUNT': 989970.39, 'MIN_TOTAL_AMOUNT': -400.0}
# {'YEAR': 2015, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 12712081, 'AVG_DISTANCE': 14.03, 'MAX_DISTANCE': 15420004.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.1, 'MAX_TOTAL_AMOUNT': 3950611.6, 'MIN_TOTAL_AMOUNT': -450.3}
# {'YEAR': 2015, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1576643, 'AVG_DISTANCE': 2.77, 'MAX_DISTANCE': 659.58, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.49, 'MAX_TOTAL_AMOUNT': 3532.1, 'MIN_TOTAL_AMOUNT': -259.33}
# {'YEAR': 2015, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 12445256, 'AVG_DISTANCE': 9.47, 'MAX_DISTANCE': 14731432.8, 'MIN_DISTANCE': -40840124.4, 'AVG_TOTAL_AMOUNT': 15.4, 'MAX_TOTAL_AMOUNT': 322743.82, 'MIN_TOTAL_AMOUNT': -496.3}
# {'YEAR': 2015, 'MONTH': 3, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1708308, 'AVG_DISTANCE': 2.8, 'MAX_DISTANCE': 802.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.57, 'MAX_TOTAL_AMOUNT': 5660.1, 'MIN_TOTAL_AMOUNT': -495.0}
# {'YEAR': 2015, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 13266531, 'AVG_DISTANCE': 17.49, 'MAX_DISTANCE': 15420061.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.85, 'MAX_TOTAL_AMOUNT': 548463.35, 'MIN_TOTAL_AMOUNT': -270.3}
# {'YEAR': 2015, 'MONTH': 4, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1666810, 'AVG_DISTANCE': 2.88, 'MAX_DISTANCE': 375.64, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.82, 'MAX_TOTAL_AMOUNT': 4035.46, 'MIN_TOTAL_AMOUNT': -499.0}
# {'YEAR': 2015, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 13080198, 'AVG_DISTANCE': 31.45, 'MAX_DISTANCE': 59016609.3, 'MIN_DISTANCE': -186318.4, 'AVG_TOTAL_AMOUNT': 16.04, 'MAX_TOTAL_AMOUNT': 650262.85, 'MIN_TOTAL_AMOUNT': -368.3}
# {'YEAR': 2015, 'MONTH': 5, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1784850, 'AVG_DISTANCE': 2.98, 'MAX_DISTANCE': 310.99, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.25, 'MAX_TOTAL_AMOUNT': 8011.3, 'MIN_TOTAL_AMOUNT': -444.44}
# {'YEAR': 2015, 'MONTH': 5, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 13137027, 'AVG_DISTANCE': 13.65, 'MAX_DISTANCE': 15700000.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.44, 'MAX_TOTAL_AMOUNT': 75797.32, 'MIN_TOTAL_AMOUNT': -400.8}
# {'YEAR': 2015, 'MONTH': 6, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1639130, 'AVG_DISTANCE': 2.89, 'MAX_DISTANCE': 439.53, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.96, 'MAX_TOTAL_AMOUNT': 1229.8, 'MIN_TOTAL_AMOUNT': -360.0}
# {'YEAR': 2015, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 12331548, 'AVG_DISTANCE': 11.82, 'MAX_DISTANCE': 10083318.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.37, 'MAX_TOTAL_AMOUNT': 335414.49, 'MIN_TOTAL_AMOUNT': -300.0}
# {'YEAR': 2015, 'MONTH': 7, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1550979, 'AVG_DISTANCE': 2.95, 'MAX_DISTANCE': 219.82, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.91, 'MAX_TOTAL_AMOUNT': 5793.14, 'MIN_TOTAL_AMOUNT': -384.2}
# {'YEAR': 2015, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11602557, 'AVG_DISTANCE': 7.28, 'MAX_DISTANCE': 10083357.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.14, 'MAX_TOTAL_AMOUNT': 186132.54, 'MIN_TOTAL_AMOUNT': -425.3}
# {'YEAR': 2015, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1521612, 'AVG_DISTANCE': 3.0, 'MAX_DISTANCE': 586.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.93, 'MAX_TOTAL_AMOUNT': 6701.55, 'MIN_TOTAL_AMOUNT': -400.0}
# {'YEAR': 2015, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11069551, 'AVG_DISTANCE': 7.87, 'MAX_DISTANCE': 12112005.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.15, 'MAX_TOTAL_AMOUNT': 107445.09, 'MIN_TOTAL_AMOUNT': -400.8}
# {'YEAR': 2015, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1495832, 'AVG_DISTANCE': 2.97, 'MAX_DISTANCE': 603.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.03, 'MAX_TOTAL_AMOUNT': 581.3, 'MIN_TOTAL_AMOUNT': -475.0}
# {'YEAR': 2015, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11227254, 'AVG_DISTANCE': 7.06, 'MAX_DISTANCE': 14680701.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.49, 'MAX_TOTAL_AMOUNT': 410267.66, 'MIN_TOTAL_AMOUNT': -470.8}
# {'YEAR': 2015, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1650711, 'AVG_DISTANCE': 2.87, 'MAX_DISTANCE': 675.51, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.91, 'MAX_TOTAL_AMOUNT': 1253.3, 'MIN_TOTAL_AMOUNT': -450.0}
# {'YEAR': 2015, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 12384253, 'AVG_DISTANCE': 4.22, 'MAX_DISTANCE': 3008331.8, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.53, 'MAX_TOTAL_AMOUNT': 187444.26, 'MIN_TOTAL_AMOUNT': -492.8}
# {'YEAR': 2015, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1508904, 'AVG_DISTANCE': 2.84, 'MAX_DISTANCE': 192.38, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.67, 'MAX_TOTAL_AMOUNT': 1020.29, 'MIN_TOTAL_AMOUNT': -499.0}
# {'YEAR': 2015, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11219736, 'AVG_DISTANCE': 9.16, 'MAX_DISTANCE': 15000018.6, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.36, 'MAX_TOTAL_AMOUNT': 93978.1, 'MIN_TOTAL_AMOUNT': -425.8}
# {'YEAR': 2015, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1635227, 'AVG_DISTANCE': 2.84, 'MAX_DISTANCE': 236.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.77, 'MAX_TOTAL_AMOUNT': 644.8, 'MIN_TOTAL_AMOUNT': -499.0}
# {'YEAR': 2015, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 11549751, 'AVG_DISTANCE': 5.12, 'MAX_DISTANCE': 15200400.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.42, 'MAX_TOTAL_AMOUNT': 826039.97, 'MIN_TOTAL_AMOUNT': -433.3}
# {'YEAR': 2016, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1418896, 'AVG_DISTANCE': 2.74, 'MAX_DISTANCE': 360.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.38, 'MAX_TOTAL_AMOUNT': 1000.8, 'MIN_TOTAL_AMOUNT': -497.5}
# {'YEAR': 2016, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10789100, 'AVG_DISTANCE': 4.51, 'MAX_DISTANCE': 8000010.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.63, 'MAX_TOTAL_AMOUNT': 111271.65, 'MIN_TOTAL_AMOUNT': -958.4}
# {'YEAR': 2016, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1510213, 'AVG_DISTANCE': 2.73, 'MAX_DISTANCE': 235.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.21, 'MAX_TOTAL_AMOUNT': 1121.16, 'MIN_TOTAL_AMOUNT': -400.0}
# {'YEAR': 2016, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 17611, 'AVG_DISTANCE': 3.88, 'MAX_DISTANCE': 160.8, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.34, 'MAX_TOTAL_AMOUNT': 832.8, 'MIN_TOTAL_AMOUNT': -47.3}
# {'YEAR': 2016, 'MONTH': 3, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1578112, 'AVG_DISTANCE': 2.79, 'MAX_DISTANCE': 301.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.47, 'MAX_TOTAL_AMOUNT': 637.8, 'MIN_TOTAL_AMOUNT': -450.0}
# {'YEAR': 2016, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES':
 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1247295, 'AVG_DISTANCE': 2.77, 'MAX_DISTANCE': 698.56, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.6, 'MAX_TOTAL_AMOUNT': 5006.3, 'MIN_TOTAL_AMOUNT': -315.0}
# {'YEAR': 2016, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10820925, 'AVG_DISTANCE': 5.5, 'MAX_DISTANCE': 10083318.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.65, 'MAX_TOTAL_AMOUNT': 379183.74, 'MIN_TOTAL_AMOUNT': -400.3}
# {'YEAR': 2016, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1147264, 'AVG_DISTANCE': 2.66, 'MAX_DISTANCE': 213.8, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.27, 'MAX_TOTAL_AMOUNT': 676.8, 'MIN_TOTAL_AMOUNT': -499.0}
# {'YEAR': 2016, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10074983, 'AVG_DISTANCE': 2.98, 'MAX_DISTANCE': 318000.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.63, 'MAX_TOTAL_AMOUNT': 200547.51, 'MIN_TOTAL_AMOUNT': -480.8}
# {'YEAR': 2016, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1240203, 'AVG_DISTANCE': 2.63, 'MAX_DISTANCE': 147.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.03, 'MAX_TOTAL_AMOUNT': 1008.3, 'MIN_TOTAL_AMOUNT': -499.0}
# {'YEAR': 2016, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 96376, 'AVG_DISTANCE': 3.24, 'MAX_DISTANCE': 67.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.2, 'MAX_TOTAL_AMOUNT': 538580.0, 'MIN_TOTAL_AMOUNT': -53.05}
# {'YEAR': 2017, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1053046, 'AVG_DISTANCE': 2.56, 'MAX_DISTANCE': 171.65, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 13.59, 'MAX_TOTAL_AMOUNT': 621.3, 'MIN_TOTAL_AMOUNT': -180.0}
# {'YEAR': 2017, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 9631943, 'AVG_DISTANCE': 2.81, 'MAX_DISTANCE': 264.71, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.46, 'MAX_TOTAL_AMOUNT': 625901.6, 'MIN_TOTAL_AMOUNT': -350.3}
# {'YEAR': 2017, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1022626, 'AVG_DISTANCE': 2.6, 'MAX_DISTANCE': 167.7, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 13.8, 'MAX_TOTAL_AMOUNT': 1612.88, 'MIN_TOTAL_AMOUNT': -218.08}
# {'YEAR': 2017, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 9172462, 'AVG_DISTANCE': 2.8, 'MAX_DISTANCE': 324.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.64, 'MAX_TOTAL_AMOUNT': 361772.02, 'MIN_TOTAL_AMOUNT': -235.8}
# {'YEAR': 2017, 'MONTH': 3, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1162056, 'AVG_DISTANCE': 2.56, 'MAX_DISTANCE': 183.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 13.83, 'MAX_TOTAL_AMOUNT': 8999.91, 'MIN_TOTAL_AMOUNT': -480.0}
# {'YEAR': 2017, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10327283, 'AVG_DISTANCE': 2.89, 'MAX_DISTANCE': 598.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.22, 'MAX_TOTAL_AMOUNT': 171863.58, 'MIN_TOTAL_AMOUNT': -308.8}
# {'YEAR': 2017, 'MONTH': 4, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1076192, 'AVG_DISTANCE': 2.66, 'MAX_DISTANCE': 128.6, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.09, 'MAX_TOTAL_AMOUNT': 3051.3, 'MIN_TOTAL_AMOUNT': -215.0}
# {'YEAR': 2017, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10008705, 'AVG_DISTANCE': 2.96, 'MAX_DISTANCE': 308.02, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.35, 'MAX_TOTAL_AMOUNT': 538482.68, 'MIN_TOTAL_AMOUNT': -398.3}
# {'YEAR': 2017, 'MONTH': 5, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1059589, 'AVG_DISTANCE': 2.67, 'MAX_DISTANCE': 140.24, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.36, 'MAX_TOTAL_AMOUNT': 2915.8, 'MIN_TOTAL_AMOUNT': -150.0}
# {'YEAR': 2017, 'MONTH': 5, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 10107490, 'AVG_DISTANCE': 2.99, 'MAX_DISTANCE': 1514.91, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.76, 'MAX_TOTAL_AMOUNT': 861611.05, 'MIN_TOTAL_AMOUNT': -490.8}
# {'YEAR': 2017, 'MONTH': 6, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 980530, 'AVG_DISTANCE': 2.71, 'MAX_DISTANCE': 170.59, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.51, 'MAX_TOTAL_AMOUNT': 663.32, 'MIN_TOTAL_AMOUNT': -359.9}
# {'YEAR': 2017, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 9677716, 'AVG_DISTANCE': 2.98, 'MAX_DISTANCE': 9496.98, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.65, 'MAX_TOTAL_AMOUNT': 630463.12, 'MIN_TOTAL_AMOUNT': -550.3}
# {'YEAR': 2017, 'MONTH': 7, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 910193, 'AVG_DISTANCE': 2.78, 'MAX_DISTANCE': 130.53, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.47, 'MAX_TOTAL_AMOUNT': 1899.8, 'MIN_TOTAL_AMOUNT': -170.0}
# {'YEAR': 2017, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8562218, 'AVG_DISTANCE': 3.01, 'MAX_DISTANCE': 831.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.37, 'MAX_TOTAL_AMOUNT': 6667.45, 'MIN_TOTAL_AMOUNT': -450.3}
# {'YEAR': 2017, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 868481, 'AVG_DISTANCE': 2.79, 'MAX_DISTANCE': 640.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.51, 'MAX_TOTAL_AMOUNT': 2047.8, 'MIN_TOTAL_AMOUNT': -470.0}
# {'YEAR': 2017, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8408728, 'AVG_DISTANCE': 3.03, 'MAX_DISTANCE': 8557.51, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.47, 'MAX_TOTAL_AMOUNT': 307045.18, 'MIN_TOTAL_AMOUNT': -450.8}
# {'YEAR': 2017, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 886164, 'AVG_DISTANCE': 2.83, 'MAX_DISTANCE': 107.7, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.86, 'MAX_TOTAL_AMOUNT': 2669.3, 'MIN_TOTAL_AMOUNT': -450.0}
# {'YEAR': 2017, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6, 'AVG_DISTANCE': 0.77, 'MAX_DISTANCE': 2.72, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 6.16, 'MAX_TOTAL_AMOUNT': 14.16, 'MIN_TOTAL_AMOUNT': 1.8}
# {'YEAR': 2017, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 921718, 'AVG_DISTANCE': 2.76, 'MAX_DISTANCE': 167.94, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.58, 'MAX_TOTAL_AMOUNT': 2393.8, 'MIN_TOTAL_AMOUNT': -400.09}
# {'YEAR': 2017, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 874326, 'AVG_DISTANCE': 2.7, 'MAX_DISTANCE': 220.08, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 14.38, 'MAX_TOTAL_AMOUNT': 6004.3, 'MIN_TOTAL_AMOUNT': -150.0}
# {'YEAR': 2017, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES':
 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8726887, 'AVG_DISTANCE': 3.01, 'MAX_DISTANCE': 833.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.65, 'MAX_TOTAL_AMOUNT': 8019.6, 'MIN_TOTAL_AMOUNT': -333.25}
# {'YEAR': 2018, 'MONTH': 7, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 681593, 'AVG_DISTANCE': 3.31, 'MAX_DISTANCE': 159.01, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.06, 'MAX_TOTAL_AMOUNT': 2113.8, 'MIN_TOTAL_AMOUNT': -200.03}
# {'YEAR': 2018, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7830073, 'AVG_DISTANCE': 3.01, 'MAX_DISTANCE': 7655.76, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.6, 'MAX_TOTAL_AMOUNT': 730923.96, 'MIN_TOTAL_AMOUNT': -498.8}
# {'YEAR': 2018, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 677779, 'AVG_DISTANCE': 3.48, 'MAX_DISTANCE': 151.13, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.67, 'MAX_TOTAL_AMOUNT': 2872.8, 'MIN_TOTAL_AMOUNT': -255.55}
# {'YEAR': 2018, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7870561, 'AVG_DISTANCE': 3.03, 'MAX_DISTANCE': 5381.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.62, 'MAX_TOTAL_AMOUNT': 907071.04, 'MIN_TOTAL_AMOUNT': -400.3}
# {'YEAR': 2018, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 679789, 'AVG_DISTANCE': 3.58, 'MAX_DISTANCE': 8005.68, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.33, 'MAX_TOTAL_AMOUNT': 8013.3, 'MIN_TOTAL_AMOUNT': -70.0}
# {'YEAR': 2018, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8028168, 'AVG_DISTANCE': 3.01, 'MAX_DISTANCE': 329.63, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.86, 'MAX_TOTAL_AMOUNT': 7012.8, 'MIN_TOTAL_AMOUNT': -800.3}
# {'YEAR': 2018, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 732679, 'AVG_DISTANCE': 3.62, 'MAX_DISTANCE': 87.13, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.6, 'MAX_TOTAL_AMOUNT': 900.0, 'MIN_TOTAL_AMOUNT': -152.91}
# {'YEAR': 2018, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8851313, 'AVG_DISTANCE': 3.0, 'MAX_DISTANCE': 302.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.0, 'MAX_TOTAL_AMOUNT': 403408.18, 'MIN_TOTAL_AMOUNT': -475.3}
# {'YEAR': 2018, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 674956, 'AVG_DISTANCE': 3.6, 'MAX_DISTANCE': 130.47, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.48, 'MAX_TOTAL_AMOUNT': 585.3, 'MIN_TOTAL_AMOUNT': -100.0}
# {'YEAR': 2018, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8178925, 'AVG_DISTANCE': 2.94, 'MAX_DISTANCE': 932.9, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.83, 'MAX_TOTAL_AMOUNT': 187437.76, 'MIN_TOTAL_AMOUNT': -450.3}
# {'YEAR': 2018, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 721447, 'AVG_DISTANCE': 3.72, 'MAX_DISTANCE': 105.13, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.87, 'MAX_TOTAL_AMOUNT': 500.0, 'MIN_TOTAL_AMOUNT': -500.0}
# {'YEAR': 2018, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8206062, 'AVG_DISTANCE': 2.91, 'MAX_DISTANCE': 602.3, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 16.62, 'MAX_TOTAL_AMOUNT': 325478.98, 'MIN_TOTAL_AMOUNT': -300.3}
# {'YEAR': 2019, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 667954, 'AVG_DISTANCE': 3.81, 'MAX_DISTANCE': 117.99, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.97, 'MAX_TOTAL_AMOUNT': 400.0, 'MIN_TOTAL_AMOUNT': -120.0}
# {'YEAR': 2019, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7653771, 'AVG_DISTANCE': 2.83, 'MAX_DISTANCE': 831.8, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 15.81, 'MAX_TOTAL_AMOUNT': 623261.66, 'MIN_TOTAL_AMOUNT': -362.8}
# {'YEAR': 2019, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 615659, 'AVG_DISTANCE': 3.9, 'MAX_DISTANCE': 666.6, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.78, 'MAX_TOTAL_AMOUNT': 4012.3, 'MIN_TOTAL_AMOUNT': -249.3}
# {'YEAR': 2019, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7051959, 'AVG_DISTANCE': 2.92, 'MAX_DISTANCE': 701.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.7, 'MAX_TOTAL_AMOUNT': 671124.94, 'MIN_TOTAL_AMOUNT': -400.8}
# {'YEAR': 2019, 'MONTH': 3, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 642571, 'AVG_DISTANCE': 3.85, 'MAX_DISTANCE': 603.8, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.54, 'MAX_TOTAL_AMOUNT': 944.98, 'MIN_TOTAL_AMOUNT': -890.3}
# {'YEAR': 2019, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7853793, 'AVG_DISTANCE': 3.02, 'MAX_DISTANCE': 237.17, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.31, 'MAX_TOTAL_AMOUNT': 1084772.17, 'MIN_TOTAL_AMOUNT': -450.3}
# {'YEAR': 2019, 'MONTH': 4, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 567868, 'AVG_DISTANCE': 3.52, 'MAX_DISTANCE': 101.53, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.38, 'MAX_TOTAL_AMOUNT': 2438.8, 'MIN_TOTAL_AMOUNT': -130.08}
# {'YEAR': 2019, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7480302, 'AVG_DISTANCE': 3.04, 'MAX_DISTANCE': 830.9, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.4, 'MAX_TOTAL_AMOUNT': 395841.24, 'MIN_TOTAL_AMOUNT': -450.88}
# {'YEAR': 2019, 'MONTH': 5, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 546429, 'AVG_DISTANCE': 3.37, 'MAX_DISTANCE': 117.23, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.13, 'MAX_TOTAL_AMOUNT': 1541.3, 'MIN_TOTAL_AMOUNT': -245.0}
# {'YEAR': 2019, 'MONTH': 5, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7619822, 'AVG_DISTANCE': 3.06, 'MAX_DISTANCE': 401.4, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.66, 'MAX_TOTAL_AMOUNT': 4020.3, 'MIN_TOTAL_AMOUNT': -378.3}
# {'YEAR': 2019, 'MONTH': 6, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 505404, 'AVG_DISTANCE': 3.35, 'MAX_DISTANCE': 202.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.5, 'MAX_TOTAL_AMOUNT': 2109.8, 'MIN_TOTAL_AMOUNT': -250.0}
# {'YEAR': 2019, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6951796, 'AVG_DISTANCE': 3.11, 'MAX_DISTANCE': 45977.22, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.85, 'MAX_TOTAL_AMOUNT': 347035.05, 'MIN_TOTAL_AMOUNT': -330.2}
# {'YEAR': 2019, 'MONTH': 7, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 470498, 'AVG_DISTANCE': 3.32, 'MAX_DISTANCE': 189.23, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 17.42, 'MAX_TOTAL_AMOUNT': 2017.3, 'MIN_TOTAL_AMOUNT': -80.0}
# {'YEAR': 2019, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6310215, 'AVG_DISTANCE': 3.11, 'MAX_DISTANCE': 311.56, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.62, 'MAX_TOTAL_AMOUNT': 6667.45, 'MIN_TOTAL_AMOUNT': -450.8}
# {'YEAR': 2019, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 450752, 'AVG_DISTANCE': 3.48, 'MAX_DISTANCE': 112.95, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.19, 'MAX_TOTAL_AMOUNT': 1958.8, 'MIN_TOTAL_AMOUNT': -350.0}
# {'YEAR': 2019, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6080266, 'AVG_DISTANCE': 3.16, 'MAX_DISTANCE': 601.6, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.67, 'MAX_TOTAL_AMOUNT': 411042.81, 'MIN_TOTAL_AMOUNT': -1871.8}
# {'YEAR': 2019, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 447822, 'AVG_DISTANCE': 3.52, 'MAX_DISTANCE': 341.64, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 18.62, 'MAX_TOTAL_AMOUNT': 1762.8, 'MIN_TOTAL_AMOUNT': -200.0}
# {'YEAR': 2019, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6554195, 'AVG_DISTANCE': 3.09, 'MAX_DISTANCE': 603.5, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.92, 'MAX_TOTAL_AMOUNT': 151007.81, 'MIN_TOTAL_AMOUNT': -530.8}
# {'YEAR': 2019, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 477039, 'AVG_DISTANCE': 3.54, 'MAX_DISTANCE': 515.89, 'MIN_DISTANCE': -6.93, 'AVG_TOTAL_AMOUNT': 18.98, 'MAX_TOTAL_AMOUNT': 2878.3, 'MIN_TOTAL_AMOUNT': -200.0}
# {'YEAR': 2019, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 7238135, 'AVG_DISTANCE': 3.02, 'MAX_DISTANCE': 307.95, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 19.75, 'MAX_TOTAL_AMOUNT': 2155.8, 'MIN_TOTAL_AMOUNT': -400.3}
# {'YEAR': 2019, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 449878, 'AVG_DISTANCE': 2.89, 'MAX_DISTANCE': 105.72, 'MIN_DISTANCE': -20329.08, 'AVG_TOTAL_AMOUNT': 18.71, 'MAX_TOTAL_AMOUNT': 833.33, 'MIN_TOTAL_AMOUNT': -125.0}
# {'YEAR': 2019, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6872471, 'AVG_DISTANCE': 2.93, 'MAX_DISTANCE': 701.3, 'MIN_DISTANCE': -18739.24, 'AVG_TOTAL_AMOUNT': 19.41, 'MAX_TOTAL_AMOUNT': 2254.3, 'MIN_TOTAL_AMOUNT': -400.3}
# {'YEAR': 2019, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 457460, 'AVG_DISTANCE': 3.48, 'MAX_DISTANCE': 77843.76, 'MIN_DISTANCE': -9436.33, 'AVG_TOTAL_AMOUNT': 18.79, 'MAX_TOTAL_AMOUNT': 500.3, 'MIN_TOTAL_AMOUNT': -200.0}
# {'YEAR': 2019, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 6928964, 'AVG_DISTANCE': 2.97, 'MAX_DISTANCE': 19130.18, 'MIN_DISTANCE': -37264.53, 'AVG_TOTAL_AMOUNT': 19.64, 'MAX_TOTAL_AMOUNT': 398471.2, 'MIN_TOTAL_AMOUNT': -1472.8}
# {'YEAR': 2020, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES':
 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 69110, 'AVG_DISTANCE': 96.92, 'MAX_DISTANCE': 298348.16, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 20.81, 'MAX_TOTAL_AMOUNT': 544.35, 'MIN_TOTAL_AMOUNT': -350.38}
# {'YEAR': 2022, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3194323, 'AVG_DISTANCE': 7.1, 'MAX_DISTANCE': 303133.41, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.64, 'MAX_TOTAL_AMOUNT': 187448.26, 'MIN_TOTAL_AMOUNT': -790.3}
# ...
# {'YEAR': 2023, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2859197, 'AVG_DISTANCE': 4.28, 'MAX_DISTANCE': 265869.44, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 29.75, 'MAX_TOTAL_AMOUNT': 187513.9, 'MIN_TOTAL_AMOUNT': -872.75}
# {'YEAR': 2023, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 66082, 'AVG_DISTANCE': 23.34, 'MAX_DISTANCE': 184103.35, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.78, 'MAX_TOTAL_AMOUNT': 1025.8, 'MIN_TOTAL_AMOUNT': -107.53}
# {'YEAR': 2023, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3510160, 'AVG_DISTANCE': 3.93, 'MAX_DISTANCE': 205544.17, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 29.19, 'MAX_TOTAL_AMOUNT': 6339.0, 'MIN_TOTAL_AMOUNT': -901.0}
# {'YEAR': 2023, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 63965, 'AVG_DISTANCE': 18.47, 'MAX_DISTANCE': 150445.15, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.12, 'MAX_TOTAL_AMOUNT': 3527.3, 'MIN_TOTAL_AMOUNT': -221.0}
# {'YEAR': 2023, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3342225, 'AVG_DISTANCE': 3.62, 'MAX_DISTANCE': 90771.91, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 28.69, 'MAX_TOTAL_AMOUNT': 1814.27, 'MIN_TOTAL_AMOUNT': -801.0}
# {'YEAR': 2023, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 64447, 'AVG_DISTANCE': 24.98, 'MAX_DISTANCE': 118988.71, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.26, 'MAX_TOTAL_AMOUNT': 1622.6, 'MIN_TOTAL_AMOUNT': -121.0}
# {'YEAR': 2023, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3396112, 'AVG_DISTANCE': 3.67, 'MAX_DISTANCE': 161726.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 28.54, 'MAX_TOTAL_AMOUNT': 4269.16, 'MIN_TOTAL_AMOUNT': -1094.05}
# {'YEAR': 2024, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 56285, 'AVG_DISTANCE': 31.63, 'MAX_DISTANCE': 201421.68, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.39, 'MAX_TOTAL_AMOUNT': 1424.1, 'MIN_TOTAL_AMOUNT': -76.5}
# {'YEAR': 2024, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2939833, 'AVG_DISTANCE': 3.68, 'MAX_DISTANCE': 312722.3, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.8, 'MAX_TOTAL_AMOUNT': 5000.0, 'MIN_TOTAL_AMOUNT': -900.0}
# {'YEAR': 2024, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 53608, 'AVG_DISTANCE': 17.66, 'MAX_DISTANCE': 134625.46, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.64, 'MAX_TOTAL_AMOUNT': 957.2, 'MIN_TOTAL_AMOUNT': -86.0}
# {'YEAR': 2024, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3011160, 'AVG_DISTANCE': 3.84, 'MAX_DISTANCE': 222478.29, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT':
 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.65, 'MAX_TOTAL_AMOUNT': 746.5, 'MIN_TOTAL_AMOUNT': -251.0}
# {'YEAR': 2024, 'MONTH': 9, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3623447, 'AVG_DISTANCE': 5.75, 'MAX_DISTANCE': 330397.59, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 28.55, 'MAX_TOTAL_AMOUNT': 1886.02, 'MIN_TOTAL_AMOUNT': -1000.0}
# {'YEAR': 2024, 'MONTH': 10, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 56235, 'AVG_DISTANCE': 11.39, 'MAX_DISTANCE': 116136.1, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.06, 'MAX_TOTAL_AMOUNT': 541.8, 'MIN_TOTAL_AMOUNT': -121.0}
# {'YEAR': 2024, 'MONTH': 10, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3847332, 'AVG_DISTANCE': 5.12, 'MAX_DISTANCE': 366343.04, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 28.42, 'MAX_TOTAL_AMOUNT': 1690.89, 'MIN_TOTAL_AMOUNT': -901.0}
# {'YEAR': 2024, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 52200, 'AVG_DISTANCE': 27.15, 'MAX_DISTANCE': 233972.43, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.18, 'MAX_TOTAL_AMOUNT': 800.0, 'MIN_TOTAL_AMOUNT': -131.0}
# {'YEAR': 2024, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3642417, 'AVG_DISTANCE': 5.37, 'MAX_DISTANCE': 398608.62, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 27.65, 'MAX_TOTAL_AMOUNT': 335550.94, 'MIN_TOTAL_AMOUNT': -1477.68}
# {'YEAR': 2024, 'MONTH': 12, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 54169, 'AVG_DISTANCE': 13.45, 'MAX_DISTANCE': 64935.37, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.01, 'MAX_TOTAL_AMOUNT': 706.6, 'MIN_TOTAL_AMOUNT': -251.08}
# {'YEAR': 2024, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3687435, 'AVG_DISTANCE': 5.1, 'MAX_DISTANCE': 328827.63, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 28.28, 'MAX_TOTAL_AMOUNT': 3037.1, 'MIN_TOTAL_AMOUNT': -951.0}
# {'YEAR': 2025, 'MONTH': 1, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 48115, 'AVG_DISTANCE': 21.62, 'MAX_DISTANCE': 84731.57, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.61, 'MAX_TOTAL_AMOUNT': 371.4, 'MIN_TOTAL_AMOUNT': -76.5}
# {'YEAR': 2025, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3466547, 'AVG_DISTANCE': 5.84, 'MAX_DISTANCE': 276423.57, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.61, 'MAX_TOTAL_AMOUNT': 863380.37, 'MIN_TOTAL_AMOUNT': -901.0}
# {'YEAR': 2025, 'MONTH': 2, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 46672, 'AVG_DISTANCE': 15.23, 'MAX_DISTANCE': 111597.19, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 22.88, 'MAX_TOTAL_AMOUNT': 642.14, 'MIN_TOTAL_AMOUNT': -76.5}
# {'YEAR': 2025, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3579668, 'AVG_DISTANCE': 6.05, 'MAX_DISTANCE': 228782.51, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.04, 'MAX_TOTAL_AMOUNT': 132555.41, 'MIN_TOTAL_AMOUNT': -1832.85}
# {'YEAR': 2025, 'MONTH': 3, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 51453, 'AVG_DISTANCE': 15.52, 'MAX_DISTANCE': 147993.11, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 23.95, 'MAX_TOTAL_AMOUNT': 473.1, 'MIN_TOTAL_AMOUNT': -473.1}
# {'YEAR': 2025, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4126219, 'AVG_DISTANCE': 6.61, 'MAX_DISTANCE': 320136.29, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.29, 'MAX_TOTAL_AMOUNT': 46269.44, 'MIN_TOTAL_AMOUNT': -1000.0}
# {'YEAR': 2025, 'MONTH': 4, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 52138, 'AVG_DISTANCE': 17.97, 'MAX_DISTANCE': 143684.91, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 24.63, 'MAX_TOTAL_AMOUNT': 381.0, 'MIN_TOTAL_AMOUNT': -224.0}
# {'YEAR': 2025, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3970480, 'AVG_DISTANCE': 7.01, 'MAX_DISTANCE': 386088.43, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.59, 'MAX_TOTAL_AMOUNT': 1793.37, 'MIN_TOTAL_AMOUNT': -1793.37}
# {'YEAR': 2025, 'MONTH': 5, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 55522, 'AVG_DISTANCE': 20.28, 'MAX_DISTANCE': 170400.15, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.4, 'MAX_TOTAL_AMOUNT': 1095.54, 'MIN_TOTAL_AMOUNT': -201.0}
# {'YEAR': 2025, 'MONTH': 5, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4612761, 'AVG_DISTANCE': 7.63, 'MAX_DISTANCE': 263103.98, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.86, 'MAX_TOTAL_AMOUNT': 1614.29, 'MIN_TOTAL_AMOUNT': -1147.17}
# {'YEAR': 2025, 'MONTH': 6, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 49272, 'AVG_DISTANCE': 10.13, 'MAX_DISTANCE': 77463.55, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.77, 'MAX_TOTAL_AMOUNT': 589.7, 'MIN_TOTAL_AMOUNT': -201.0}
# {'YEAR': 2025, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4301865, 'AVG_DISTANCE': 7.47, 'MAX_DISTANCE': 261262.39, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 27.42, 'MAX_TOTAL_AMOUNT': 325528.45, 'MIN_TOTAL_AMOUNT': -994.25}
# {'YEAR': 2025, 'MONTH': 7, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 48149, 'AVG_DISTANCE': 21.41, 'MAX_DISTANCE': 249852.24, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 25.68, 'MAX_TOTAL_AMOUNT': 746.0, 'MIN_TOTAL_AMOUNT': -301.0}
# {'YEAR': 2025, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3893885, 'AVG_DISTANCE': 7.11, 'MAX_DISTANCE': 397994.37, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 26.82, 'MAX_TOTAL_AMOUNT': 5297.87, 'MIN_TOTAL_AMOUNT': -1634.75}
# {'YEAR': 2025, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 3.03, 'MAX_DISTANCE': 3.62, 'MIN_DISTANCE': 1.97, 'AVG_TOTAL_AMOUNT': 26.35, 'MAX_TOTAL_AMOUNT': 34.44, 'MIN_TOTAL_AMOUNT': 16.53}
# {'YEAR': 2026, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2, 'AVG_DISTANCE': 2.0, 'MAX_DISTANCE': 3.14, 'MIN_DISTANCE': 0.85, 'AVG_TOTAL_AMOUNT': 14.3, 'MAX_TOTAL_AMOUNT': 21.8, 'MIN_TOTAL_AMOUNT': 6.8}
# {'YEAR': 2026, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2, 'AVG_DISTANCE': 5.76, 'MAX_DISTANCE': 10.96, 'MIN_DISTANCE': 0.56, 'AVG_TOTAL_AMOUNT': 43.29, 'MAX_TOTAL_AMOUNT': 73.07, 'MIN_TOTAL_AMOUNT': 13.5}
# {'YEAR': 2026, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 18.98, 'MAX_DISTANCE': 18.98, 'MIN_DISTANCE': 18.98, 'AVG_TOTAL_AMOUNT': 55.3, 'MAX_TOTAL_AMOUNT': 55.3, 'MIN_TOTAL_AMOUNT': 55.3}
# {'YEAR': 2029, 'MONTH': 5, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 5.89, 'MAX_DISTANCE': 11.51, 'MIN_DISTANCE': 1.69, 'AVG_TOTAL_AMOUNT': 26.08, 'MAX_TOTAL_AMOUNT': 35.8, 'MIN_TOTAL_AMOUNT': 12.96}
# {'YEAR': 2029, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4, 'AVG_DISTANCE': 2.67, 'MAX_DISTANCE': 9.02, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 13.43, 'MAX_TOTAL_AMOUNT': 29.8, 'MIN_TOTAL_AMOUNT': 3.8}
# {'YEAR': 2030, 'MONTH': 11, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 2, 'AVG_DISTANCE': 0.56, 'MAX_DISTANCE': 1.08, 'MIN_DISTANCE': 0.03, 'AVG_TOTAL_AMOUNT': 6.15, 'MAX_TOTAL_AMOUNT': 7.3, 'MIN_TOTAL_AMOUNT': 5.0}
# {'YEAR': 2031, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2, 'AVG_DISTANCE': 1.57, 'MAX_DISTANCE': 1.69, 'MIN_DISTANCE': 1.44, 'AVG_TOTAL_AMOUNT': 9.8, 'MAX_TOTAL_AMOUNT': 9.8, 'MIN_TOTAL_AMOUNT': 9.8}
# {'YEAR': 2032, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 23.21, 'MAX_DISTANCE': 23.21, 'MIN_DISTANCE': 23.21, 'AVG_TOTAL_AMOUNT': 63.3, 'MAX_TOTAL_AMOUNT': 63.3, 'MIN_TOTAL_AMOUNT': 63.3}
# {'YEAR': 2033, 'MONTH': 4, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 0.86, 'MAX_DISTANCE': 1.35, 'MIN_DISTANCE': 0.61, 'AVG_TOTAL_AMOUNT': 8.8, 'MAX_TOTAL_AMOUNT': 10.8, 'MIN_TOTAL_AMOUNT': 7.3}
# {'YEAR': 2035, 'MONTH': 9, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2037, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 2.99, 'MAX_DISTANCE': 2.99, 'MIN_DISTANCE': 2.99, 'AVG_TOTAL_AMOUNT': 18.0, 'MAX_TOTAL_AMOUNT': 18.0, 'MIN_TOTAL_AMOUNT': 18.0}
# {'YEAR': 2038, 'MONTH': 2, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 4, 'AVG_DISTANCE': 1.74, 'MAX_DISTANCE': 5.07, 'MIN_DISTANCE': 0.45, 'AVG_TOTAL_AMOUNT': 12.07, 'MAX_TOTAL_AMOUNT': 21.8, 'MIN_TOTAL_AMOUNT': 7.8}
# {'YEAR': 2041, 'MONTH': 3, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 2.85, 'MAX_DISTANCE': 2.85, 'MIN_DISTANCE': 2.85, 'AVG_TOTAL_AMOUNT': 15.8, 'MAX_TOTAL_AMOUNT': 15.8, 'MIN_TOTAL_AMOUNT': 15.8}
# {'YEAR': 2041, 'MONTH': 6, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 1.34, 'MAX_DISTANCE': 1.34, 'MIN_DISTANCE': 1.34, 'AVG_TOTAL_AMOUNT': 8.3, 'MAX_TOTAL_AMOUNT': 8.3, 'MIN_TOTAL_AMOUNT': 8.3}
# {'YEAR': 2041, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2042, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.29, 'MAX_DISTANCE': 0.29, 'MIN_DISTANCE': 0.29, 'AVG_TOTAL_AMOUNT': 4.8, 'MAX_TOTAL_AMOUNT': 4.8, 'MIN_TOTAL_AMOUNT': 4.8}
# {'YEAR': 2053, 'MONTH': 7, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2058, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 3, 'AVG_DISTANCE': 1.3, 'MAX_DISTANCE': 1.6, 'MIN_DISTANCE': 1.03, 'AVG_TOTAL_AMOUNT': 11.39, 'MAX_TOTAL_AMOUNT': 13.57, 'MIN_TOTAL_AMOUNT': 8.8}
# {'YEAR': 2062, 'MONTH': 8, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 3.6, 'MAX_TOTAL_AMOUNT': 3.6, 'MIN_TOTAL_AMOUNT': 3.6}
# {'YEAR': 2066, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 16.14, 'MAX_DISTANCE': 16.14, 'MIN_DISTANCE': 16.14, 'AVG_TOTAL_AMOUNT': 61.42, 'MAX_TOTAL_AMOUNT': 61.42, 'MIN_TOTAL_AMOUNT': 61.42}
# {'YEAR': 2070, 'MONTH': 8, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 0.0, 'MAX_DISTANCE': 0.0, 'MIN_DISTANCE': 0.0, 'AVG_TOTAL_AMOUNT': 0.0, 'MAX_TOTAL_AMOUNT': 0.0, 'MIN_TOTAL_AMOUNT': 0.0}
# {'YEAR': 2081, 'MONTH': 6, 'SERVICE_TYPE': 'green', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 16.95, 'MAX_DISTANCE': 16.95, 'MIN_DISTANCE': 16.95, 'AVG_TOTAL_AMOUNT': 55.96, 'MAX_TOTAL_AMOUNT': 55.96, 'MIN_TOTAL_AMOUNT': 55.96}
# {'YEAR': 2084, 'MONTH': 11, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 8, 'AVG_DISTANCE': 1.25, 'MAX_DISTANCE': 1.85, 'MIN_DISTANCE': 0.32, 'AVG_TOTAL_AMOUNT': 9.24, 'MAX_TOTAL_AMOUNT': 13.3, 'MIN_TOTAL_AMOUNT': 4.8}
# {'YEAR': 2088, 'MONTH': 1, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 2, 'AVG_DISTANCE': 2.34, 'MAX_DISTANCE': 4.05, 'MIN_DISTANCE': 0.63, 'AVG_TOTAL_AMOUNT': 10.3, 'MAX_TOTAL_AMOUNT': 15.3, 'MIN_TOTAL_AMOUNT': 5.3}
# {'YEAR': 2090, 'MONTH': 12, 'SERVICE_TYPE': 'yellow', 'TOTAL_VIAJES': 1, 'AVG_DISTANCE': 18.6, 'MAX_DISTANCE': 18.6, 'MIN_DISTANCE': 18.6, 'AVG_TOTAL_AMOUNT': 61.42, 'MAX_TOTAL_AMOUNT': 61.42, 'MIN_TOTAL_AMOUNT': 61.42}
# True

# %%
query_val = """
WITH base AS (
    SELECT *
    FROM STAGE.OBT_TRIPS
)
SELECT
    -- TOTAL DE REGISTROS
    COUNT(*) AS total_registros,
    
    -- NULOS
    COUNT_IF(PICKUP_DATETIME IS NULL) AS null_pickup_datetime,
    COUNT_IF(DROPOFF_DATETIME IS NULL) AS null_dropoff_datetime,
    COUNT_IF(PICKUP_DATE IS NULL) AS null_pickup_date,
    COUNT_IF(PU_LOCATION_ID IS NULL) AS null_pu_location,
    COUNT_IF(DO_LOCATION_ID IS NULL) AS null_do_location,
    COUNT_IF(TRIP_DISTANCE IS NULL) AS null_trip_distance,
    COUNT_IF(TOTAL_AMOUNT IS NULL) AS null_total_amount,
    COUNT_IF(SERVICE_TYPE IS NULL) AS null_service_type,
    COUNT_IF(PAYMENT_TYPE_DESC IS NULL) AS null_payment_type,

    -- RANGOS
    COUNT_IF(TRIP_DISTANCE < 0 OR TRIP_DISTANCE > 200) AS distancia_fuera_rango,
    COUNT_IF(TOTAL_AMOUNT < 0 OR TOTAL_AMOUNT > 2000) AS monto_fuera_rango,
    COUNT_IF(PASSENGER_COUNT < 0 OR PASSENGER_COUNT > 10) AS pasajeros_fuera_rango,
    COUNT_IF(AVG_SPEED_MPH < 0 OR AVG_SPEED_MPH > 120) AS velocidad_fuera_rango,
    COUNT_IF(TIP_PCT < 0 OR TIP_PCT > 100) AS tip_pct_fuera_rango,
    -- COHERENCIA DE FECHAS
    COUNT_IF(DROPOFF_DATETIME < PICKUP_DATETIME) AS dropoff_antes_pickup,
    COUNT_IF(TRIP_DURATION_MIN <= 0) AS duracion_invalida,

    -- ESTADÍSTICAS
    MIN(TRIP_DISTANCE) AS min_trip_distance,
    MAX(TRIP_DISTANCE) AS max_trip_distance,
    AVG(TRIP_DISTANCE) AS avg_trip_distance,
    
    MIN(TOTAL_AMOUNT) AS min_total_amount,
    MAX(TOTAL_AMOUNT) AS max_total_amount,
    AVG(TOTAL_AMOUNT) AS avg_total_amount,
    
    MIN(TRIP_DURATION_MIN) AS min_trip_duration,
    MAX(TRIP_DURATION_MIN) AS max_trip_duration,
    AVG(TRIP_DURATION_MIN) AS avg_trip_duration,
    
    MIN(AVG_SPEED_MPH) AS min_avg_speed,
    MAX(AVG_SPEED_MPH) AS max_avg_speed,
    AVG(AVG_SPEED_MPH) AS avg_speed,
    
    MIN(TIP_PCT) AS min_tip_pct,
    MAX(TIP_PCT) AS max_tip_pct,
    AVG(TIP_PCT) AS avg_tip_pct

FROM base;

"""

# %%
df = pd.read_sql(query_val, conn)
# Out:
# /tmp/ipykernel_28287/1336375778.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query_val, conn)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    TOTAL_REGISTROS  NULL_PICKUP_DATETIME  NULL_DROPOFF_DATETIME  \
# 0        800840342                     0                      0
#
#    NULL_PICKUP_DATE  NULL_PU_LOCATION  NULL_DO_LOCATION  NULL_TRIP_DISTANCE  \
# 0                 0                 0                 0                   0
#
#    NULL_TOTAL_AMOUNT  NULL_SERVICE_TYPE  NULL_PAYMENT_TYPE  \
# 0                  0                  0                  0
#
#    DISTANCIA_FUERA_RANGO  MONTO_FUERA_RANGO  PASAJEROS_FUERA_RANGO  \
# 0                  42882            2472271                      6
#
#    VELOCIDAD_FUERA_RANGO  TIP_PCT_FUERA_RANGO  DROPOFF_ANTES_PICKUP  \
# 0                 190827                  184                 84402
#
#    DURACION_INVALIDA  MIN_TRIP_DISTANCE  MAX_TRIP_DISTANCE  AVG_TRIP_DISTANCE  \
# 0            5830394        -40840124.4         59016609.3           5.778842
#
#    MIN_TOTAL_AMOUNT  MAX_TOTAL_AMOUNT  AVG_TOTAL_AMOUNT  MIN_TRIP_DURATION  \
# 0           -2567.8         3950611.6         18.487614          -61001725
#
#    MAX_TRIP_DURATION  AVG_TRIP_DURATION  MIN_AVG_SPEED  MAX_AVG_SPEED  \
# 0          125373161          19.343971  -2.405684e+09   3.540926e+09
#
#    AVG_SPEED  MIN_TIP_PCT   MAX_TIP_PCT  AVG_TIP_PCT
# 0   24.35337 -7933.333333  2.109288e+08    10.418488

# %%
query_snapshot = """
SELECT *
FROM STAGE.OBT_TRIPS
LIMIT 20
"""
df_snapshot = pd.read_sql(query_snapshot, conn)
df_snapshot.head()
# Out:
# /tmp/ipykernel_28287/3208590879.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_snapshot = pd.read_sql(query_snapshot, conn)
#       PICKUP_DATETIME    DROPOFF_DATETIME PICKUP_DATE  PICKUP_HOUR  \
# 0 2016-07-27 03:53:34 2016-07-27 04:17:36  2016-07-27            3
# 1 2016-07-27 03:51:59 2016-07-27 03:56:20  2016-07-27            3
# 2 2016-07-27 03:27:11 2016-07-27 03:45:30  2016-07-27            3
# 3 2016-07-27 03:31:30 2016-07-27 03:48:12  2016-07-27            3
# 4 2016-07-27 03:57:37 2016-07-27 04:01:18  2016-07-27            3
#
#   DROPOFF_DATE  DROPOFF_HOUR  DAY_OF_WEEK  MONTH  YEAR  PU_LOCATION_ID  \
# 0   2016-07-27             4            3      7  2016             138
# 1   2016-07-27             3            3      7  2016             235
# 2   2016-07-27             3            3      7  2016             170
# 3   2016-07-27             3            3      7  2016             263
# 4   2016-07-27             4            3      7  2016             141
#
#                              PU_ZONE PU_BOROUGH  DO_LOCATION_ID  \
# 0                  LaGuardia Airport     Queens             202
# 1  University Heights/Morris Heights      Bronx             235
# 2                        Murray Hill  Manhattan              75
# 3                     Yorkville West  Manhattan             162
# 4                    Lenox Hill West  Manhattan             141
#
#                              DO_ZONE DO_BOROUGH SERVICE_TYPE  VENDOR_ID  \
# 0                   Roosevelt Island  Manhattan       yellow          1
# 1  University Heights/Morris Heights      Bronx       yellow          2
# 2                  East Harlem South  Manhattan       yellow          2
# 3                       Midtown East  Manhattan       yellow          1
# 4                    Lenox Hill West  Manhattan       yellow          2
#
#                          VENDOR_NAME  RATE_CODE_ID RATE_CODE_DESC  \
# 0  Creative Mobile Technologies, LLC             1  Standard rate
# 1                 Curb Mobility, LLC             1  Standard rate
# 2                 Curb Mobility, LLC             1  Standard rate
# 3  Creative Mobile Technologies, LLC             1  Standard rate
# 4                 Curb Mobility, LLC             1  Standard rate
#
#    PAYMENT_TYPE PAYMENT_TYPE_DESC TRIP_TYPE TRIP_TYPE_DESC  PASSENGER_COUNT  \
# 0             1       Credit card      None        Unknown                1
# 1             2              Cash      None        Unknown                1
# 2             1       Credit card      None        Unknown                1
# 3             1       Credit card      None        Unknown                1
# 4             1       Credit card      None        Unknown                5
#
#    TRIP_DISTANCE STORE_AND_FWD_FLAG  FARE_AMOUNT  EXTRA  MTA_TAX  TIP_AMOUNT  \
# 0           6.30                 No         21.0    0.0      0.5        4.35
# 1           0.82                 No          5.5    0.0      0.5        0.00
# 2           3.49                 No         15.0    0.0      0.5        1.58
# 3           2.00                 No         12.0    0.0      0.5        1.66
# 4           0.62                 No          4.5    0.0      0.5        1.06
#
#    TOLLS_AMOUNT  IMPROVEMENT_SURCHARGE CONGESTION_SURCHARGE AIRPORT_FEE  \
# 0           0.0                    0.3                 None        None
# 1           0.0                    0.3                 None        None
# 2           0.0                    0.3                 None        None
# 3           0.0                    0.3                 None        None
# 4           0.0                    0.3                 None        None
#
#    TOTAL_AMOUNT  TRIP_DURATION_MIN  AVG_SPEED_MPH    TIP_PCT       RUN_ID  \
# 0         26.15                 24      15.750000  16.634799  run_2016_07
# 1          6.30                  5       9.840039   0.000000  run_2016_07
# 2         17.38                 18      11.633333   9.090909  run_2016_07
# 3         14.46                 17       7.058832  11.479945  run_2016_07
# 4          6.36                  4       9.299954  16.666667  run_2016_07
#
#              INGESTED_AT_UTC SOURCE_SERVICE  SOURCE_YEAR  SOURCE_MONTH
# 0 2025-10-20 20:35:21.429968         yellow         2016             7
# 1 2025-10-20 20:35:21.429968         yellow         2016             7
# 2 2025-10-20 20:35:21.429968         yellow         2016             7
# 3 2025-10-20 20:35:21.429968         yellow         2016             7
# 4 2025-10-20 20:35:21.429968         yellow         2016             7

# %%
conf = SparkConf()
conf.set("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.24.2,net.snowflake:spark-snowflake_2.12:3.1.2") 
spark = SparkSession.builder \
    .config(conf=conf) \
    .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 conf = SparkConf()
#       2 conf.set("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.24.2,net.snowflake:spark-snowflake_2.12:3.1.2")
#       3 spark = SparkSession.builder \
#       4     .config(conf=conf) \
#       5     .getOrCreate()
#
# File /usr/local/spark/python/pyspark/conf.py:132, in SparkConf.__init__(self, loadDefaults, _jvm, _jconf)
#     128 _jvm = _jvm or SparkContext._jvm
#     130 if _jvm is not None:
#     131     # JVM is created, so create self._jconf directly through JVM
# --> 132     self._jconf = _jvm.SparkConf(loadDefaults)
#     133     self._conf = None
#     134 else:
#     135     # JVM is not created, so store data in self._conf first
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1712, in JVMView.__getattr__(self, name)
#    1709 if name == UserHelpAutoCompletion.KEY:
#    1710     return UserHelpAutoCompletion()
# -> 1712 answer = self._gateway_client.send_command(
#    1713     proto.REFLECTION_COMMAND_NAME +
#    1714     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1715     "\n" + proto.END_COMMAND_PART)
#    1716 if answer == proto.SUCCESS_PACKAGE:
#    1717     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
# Auditoría: tabla o reporte con conteos por servicio/año/mes y run_id.

sfOptions = {
    "sfURL" : "TLZAPUN-PKC06603.snowflakecomputing.com",
    "sfDatabase" : "NY_TAXI",
    "sfSchema" : "RAW",
    "sfWarehouse" :"COMPUTE_WH",
    "sfRole" : "ACCOUNTADMIN",
    "sfUser" : "MARE122510",
    "sfPassword" : "MyTurnEra2025100%"
}


df = spark.read \
    .format("snowflake") \
    .options(**sfOptions) \
    .option("dbtable", "STAGE.OBT_TRIPS") \
    .load()

df_counts = df.groupBy("SOURCE_YEAR", "SOURCE_MONTH", "RUN_ID").count().orderBy("SOURCE_YEAR", "SOURCE_MONTH", "RUN_ID")
df_counts.show(truncate=False, n = 100)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[105], line 12
#       1 # Auditoría: tabla o reporte con conteos por servicio/año/mes y run_id.
#       3 sfOptions = {
#       4     "sfURL" : "TLZAPUN-PKC06603.snowflakecomputing.com",
#       5     "sfDatabase" : "NY_TAXI",
#    (...)
#      10     "sfPassword" : "MyTurnEra2025100%"
#      11 }
# ---> 12 conf = SparkConf()
#      13 spark = SparkSession.builder \
#      14     .appName("SnowflakeConnector") \
#      15     .config("spark.jars.packages", "net.snowflake:snowflake-jdbc:3.13.29,net.snowflake:spark-snowflake_2.12:2.9.0-spark_3.1") \
#      16     .getOrCreate()
#      19 df = spark.read \
#      20     .format("snowflake") \
#      21     .options(**sfOptions) \
#      22     .option("dbtable", "STAGE.OBT_TRIPS") \
#      23     .load()
#
# File /usr/local/spark/python/pyspark/conf.py:132, in SparkConf.__init__(self, loadDefaults, _jvm, _jconf)
#     128 _jvm = _jvm or SparkContext._jvm
#     130 if _jvm is not None:
#     131     # JVM is created, so create self._jconf directly through JVM
# --> 132     self._jconf = _jvm.SparkConf(loadDefaults)
#     133     self._conf = None
#     134 else:
#     135     # JVM is not created, so store data in self._conf first
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1712, in JVMView.__getattr__(self, name)
#    1709 if name == UserHelpAutoCompletion.KEY:
#    1710     return UserHelpAutoCompletion()
# -> 1712 answer = self._gateway_client.send_command(
#    1713     proto.REFLECTION_COMMAND_NAME +
#    1714     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1715     "\n" + proto.END_COMMAND_PART)
#    1716 if answer == proto.SUCCESS_PACKAGE:
#    1717     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused
